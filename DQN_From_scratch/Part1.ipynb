# %%
# !pip3 install gymnasium
# Out:
# Requirement already satisfied: gymnasium in s:\studies\ub\reinforcment learning\rlenv\lib\site-packages (1.0.0)
# Requirement already satisfied: numpy>=1.21.0 in s:\studies\ub\reinforcment learning\rlenv\lib\site-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in s:\studies\ub\reinforcment learning\rlenv\lib\site-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in s:\studies\ub\reinforcment learning\rlenv\lib\site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in s:\studies\ub\reinforcment learning\rlenv\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: importlib-metadata>=4.8.0 in s:\studies\ub\reinforcment learning\rlenv\lib\site-packages (from gymnasium) (8.6.1)
# Requirement already satisfied: zipp>=3.20 in s:\studies\ub\reinforcment learning\rlenv\lib\site-packages (from importlib-metadata>=4.8.0->gymnasium) (3.21.0)

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import gymnasium as gym
from collections import deque
import random
import matplotlib.pyplot as plt
from gymnasium import spaces
import pickle
from PIL import Image
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
import os
import cv2

# %%
class QNetwork(nn.Module):                                               #This is the class used to build neural network for policy training
    def __init__(self, input_dim, output_dim):
        super(QNetwork, self).__init__()
        self.fc1 = nn.Linear(input_dim, 64)
        self.fc2 = nn.Linear(64, 64)
        self.fc3 = nn.Linear(64, output_dim)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        return self.fc3(x)

# %%
class DQNAgent:
    def __init__(self, input_dim, output_dim):
        self.qnet = QNetwork(input_dim, output_dim)                                         #initializing neural networks for both online and traget network
        self.targetnet = QNetwork(input_dim, output_dim)
        self.targetnet.load_state_dict(self.qnet.state_dict())          #here we are copying the weights of online net to target net so that both start with same weights 
        self.optimizer = optim.Adam(self.qnet.parameters(), lr=0.001)      
        self.memory = deque(maxlen=10000)               #initializing the buffer to keep the experiences to replay it later
        self.batchSize = 64
        self.gamma = 0.99
        self.epsi = 1.0
        self.epsilon_min = 0.01
        self.epsilon_decay = 0.995
        self.updateTar = 100
        self.stepsCount = 0

    def actionFun(self, state):
        if np.random.rand() < self.epsi:                             #Action is taken in a epsilon greedy way 
            return np.random.randint(self.qnet.fc3.out_features)
        with torch.no_grad():
            q_values = self.qnet(state)
            return torch.argmax(q_values).item()

    def addExptoBuff(self, state, action, reward, nxt_st, done):        #THis function helps us to add the experiences to the buffer
        self.memory.append((state, action, reward, nxt_st, done))

    def replay(self):
        if len(self.memory) < self.batchSize:
            return
        batch = random.sample(self.memory, self.batchSize)  #here we are taking random 64 samples from the buffer to train the model
        states, actions, rewards, nxt_states, dones = zip(*batch)   
        states = torch.stack(states)
        actions = torch.tensor(actions, dtype=torch.long)          #Now converting everthing to tensor
        rewards = torch.tensor(rewards, dtype=torch.float32)
        nxt_states = torch.stack(nxt_states)
        dones = torch.tensor(dones, dtype=torch.float32)

        current_q = self.qnet(states).gather(1, actions.unsqueeze(1)).squeeze(1)       #this is the formula of DQN. The gather function selects the qvalue wrt the action
        next_q = self.targetnet(nxt_states).max(1)[0]          
        target_q = rewards + self.gamma * next_q * (1 - dones)

        loss = nn.functional.mse_loss(current_q, target_q)               #The mse loss is taken here
        self.optimizer.zero_grad()                               #First we clear the gradient vals
        loss.backward()                                                 #this step computes the gradient 
        self.optimizer.step()                             #here we update the q network params
        self.epsi = max(self.epsilon_min, self.epsi * self.epsilon_decay)
        self.stepsCount += 1
        if self.stepsCount >= self.updateTar:
            self.targetnet.load_state_dict(self.qnet.state_dict())
            self.stepsCount = 0

# %%
class AutoDrone(gym.Env):
    def __init__(self):
        super(AutoDrone, self).__init__()
        self.grid_size = 6
        self.action_space = spaces.Discrete(6)
        self.obs_space = spaces.Tuple((spaces.Discrete(self.grid_size),spaces.Discrete(self.grid_size),spaces.Discrete(2)))
        self.warehouse = (0, 0)
        self.delivery = (5, 5)
        self.nofly = {(2,2), (2,3), (3,2), (3,3)}
        self.reset()

    def reset(self, seed=None, options=None):
        super().reset(seed=seed)
        while True:
            self.pos = (self.np_random.integers(6), self.np_random.integers(6))
            if self.pos not in self.nofly: break
        self.has_package = False
        return (self.pos[0], self.pos[1], int(self.has_package)), {}

    def step(self, action):
        x, y = self.pos
        reward = -1
        terminated = False
        if action < 4:
            new_pos = [(x, min(y+1, 5)), (x, max(y-1, 0)),(max(x-1, 0), y), (min(x+1, 5), y)][action]
            if new_pos in self.nofly:
                reward = -100
                terminated = True
            else:
                self.pos = new_pos
        elif action == 4:  # Pick
            if self.pos == self.warehouse and not self.has_package:
                self.has_package = True
                reward = 25
            else:
                reward = -10
        elif action == 5:  # Drop
            if self.pos == self.delivery and self.has_package:
                reward = 100
                terminated = True
            else:
                reward = -10
        return (self.pos[0], self.pos[1], int(self.has_package)), reward, terminated, False, {}
    
    def render(self, mode='human', plot=False):
        fig, ax = plt.subplots()

        def plot_image(plot_pos):
            drone = False
            droneAndpackage = False
            warehouse = False
            delivery_point = False
            noFlyZ = False
            cld = False
            fixed_size = (60, 50)  
            def preprocessImg(image_path):
                normalized_path = os.path.normpath(image_path)
                if not os.path.exists(normalized_path):
                    print(f"Error: Image not found at {normalized_path}")
                    return None
                img = plt.imread(normalized_path)
                resized_img = cv2.resize(img, fixed_size, interpolation=cv2.INTER_AREA)
                return resized_img
            
            plot_pos = np.array(plot_pos)
            if np.array_equal(plot_pos, self.pos) and not self.has_package:
                drone = True
            elif np.array_equal(plot_pos, self.pos) and self.has_package:
                droneAndpackage = True
            elif np.array_equal(plot_pos, self.warehouse):
                warehouse = True
            elif np.array_equal(plot_pos, self.delivery):
                delivery_point = True
            elif tuple(plot_pos) in self.nofly:
                noFlyZ = True
            else:
                cld = True

            if drone and all(not item for item in [droneAndpackage, warehouse, delivery_point, noFlyZ, cld]):
                drone_img = preprocessImg('./images/drone.jpg')
                if drone_img is not None:
                    drone_box = AnnotationBbox(OffsetImage(drone_img, zoom=1), np.add(plot_pos, [0.5, 0.5]), frameon=False)
                    ax.add_artist(drone_box)

            elif droneAndpackage and all(not item for item in [drone, warehouse, delivery_point, noFlyZ, cld]):
                drone_package_img = preprocessImg('./images/drone+package.jpg')
                if drone_package_img is not None:
                    drone_package_box = AnnotationBbox(OffsetImage(drone_package_img, zoom=1), np.add(plot_pos, [0.5, 0.5]), frameon=False)
                    ax.add_artist(drone_package_box)

            elif warehouse and all(not item for item in [drone, droneAndpackage, delivery_point, noFlyZ, cld]):
                warehouse_img = preprocessImg('./images/warehouse.jpg')
                if warehouse_img is not None:
                    warehouse_box = AnnotationBbox(OffsetImage(warehouse_img, zoom=1), np.add(plot_pos, [0.5, 0.5]), frameon=False)
                    ax.add_artist(warehouse_box)

            elif delivery_point and all(not item for item in [drone, droneAndpackage, warehouse, noFlyZ, cld]):
                delivery_img = preprocessImg('./images/deliveryHouse.jpg')
                if delivery_img is not None:
                    delivery_box = AnnotationBbox(OffsetImage(delivery_img, zoom=1), np.add(plot_pos, [0.5, 0.5]), frameon=False)
                    ax.add_artist(delivery_box)

            elif noFlyZ and all(not item for item in [drone, droneAndpackage, warehouse, delivery_point, cld]):
                nofly_img = preprocessImg('./images/noflyzone.jpg')
                if nofly_img is not None:
                    nofly_box = AnnotationBbox(OffsetImage(nofly_img, zoom=1), np.add(plot_pos, [0.5, 0.5]), frameon=False) 
                    ax.add_artist(nofly_box)

            elif cld and all(not item for item in [drone, droneAndpackage, warehouse, delivery_point, noFlyZ]):
                cld_img = preprocessImg('./images/clouds.jpg')
                if cld_img is not None:
                    cld_box = AnnotationBbox(OffsetImage(cld_img, zoom=1),
                                        np.add(plot_pos, [0.5, 0.5]), frameon=False)
                    ax.add_artist(cld_box)

        mapping = {}
        for j in range(self.grid_size * self.grid_size):
            mapping[j] = np.array([j % self.grid_size, int(np.floor(j / self.grid_size))])

        for position in mapping:
            plot_image(mapping[position])

        plt.xticks(range(self.grid_size + 1))
        plt.yticks(range(self.grid_size + 1))
        plt.grid()
        plt.title('Drone Environment')

        if plot:
            plt.show()
        else:
            fig.canvas.draw()
            img = np.array(fig.canvas.renderer.buffer_rgba())[:, :, :3]
            width = height = 100
            preprocessed_image = cv2.resize(img, (width, height), interpolation=cv2.INTER_AREA)
            plt.show()
            plt.pause(0.1)
            return preprocessed_image

def processDronestate(obs):
    x, y, package = obs
    return torch.tensor([x/5.0, y/5.0, package], dtype=torch.float32)   #we are normalizing the x and y to make the values between 0 and 1

# %%
def train_autodrone(agent, episodes=1000):
    env = AutoDrone()        
    rewards = []
    epsilons = []
    
    for episode in range(episodes): 
        state, _ = env.reset()          #First we reset the env
        state = processDronestate(state)
        totalReward = 0
        done = False
        
        while not done:            #We run this loop until the episode ends
            action = agent.actionFun(state)             #Selecting the action through epsilon greedy
            nxt_st, reward, done, _, _ = env.step(action)     #Performing that action and getting respective reward, next state and other infos etc
            nxt_st = processDronestate(nxt_st) 
            agent.addExptoBuff(state, action, reward, nxt_st, done)      #Adding this set to the buffer
            agent.replay()          #Taking random actions from buffer to train
            state = nxt_st
            totalReward += reward 
        rewards.append(totalReward)
        epsilons.append(agent.epsi)
        if (episode+1) % 100 == 0:
            avg = np.mean(rewards[-100:])
            print(f"The episode number is {episode+1} for this we got average reward as: {avg:.2f} and the current epsilon value is: {agent.epsi:.2f}")
    np.save("droneDQN_rewards.npy", rewards)
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)                                                   #plotting the graphs of reward vs eps 
    plt.plot(rewards)
    plt.title(f"{env} Training Rewards")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    
    plt.subplot(1,2,2)
    plt.plot(epsilons)
    plt.title("Epsilon Decay")
    plt.xlabel("Episode")                                   #plotting the graph of epsilon vs eps
    plt.ylabel("Epsilon Value")
    plt.show()
    plt.close()
    return agent

# %%
def processPolestate(obs):
    return torch.tensor(obs, dtype=torch.float32)

def train_cartpole(episodes=500):
    env = gym.make('CartPole-v1')
    assert env.spec.max_episode_steps == 500, "Max episode steps should be 500"
    agent = DQNAgent(input_dim=4, output_dim=2)         #Creating a object of DQN class (basically creating agent)
    rewards = []
    epsilons = []
    for episode in range(episodes):
        state, _ = env.reset()    #Resetting the env at beginning of episode
        state = processPolestate(state)
        totalReward = 0
        while True:
            action = agent.actionFun(state)            #Selecting the action through epsilon greedy
            nxt_st, reward, terminated, truncated, _ = env.step(action)   #Performing that action and getting respective reward, next state and other infos etc
            nxt_st = processPolestate(nxt_st)
            done = terminated or truncated 
            agent.addExptoBuff(state, action, reward, nxt_st, done)  #Adding this set to the buffer
            agent.replay()
            state = nxt_st
            totalReward += reward
            if done:
                break  
        rewards.append(totalReward)
        epsilons.append(agent.epsi)  
        if (episode + 1) % 100 == 0:
            avg_reward = np.mean(rewards[-100:])
            print(f"The episode number is {episode+1} for this we got average reward as: {avg_reward:.2f} the current epsilon value is: {agent.epsi:.2f}")
    np.save("cartdqn_rewards.npy", rewards)
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(rewards)
    plt.title(f"{env} Training Rewards")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.subplot(1,2,2)
    plt.plot(epsilons)
    plt.title("Epsilon Decay")
    plt.xlabel("Episode")
    plt.ylabel("Epsilon Value")
    plt.show()
    plt.close()

    return agent

# %%
def processLakestate(obs):
    state = np.zeros(16)
    state[obs] = 1.0
    return torch.tensor(state, dtype=torch.float32)

def train_frozenlake(episodes=2000):
    env = gym.make('FrozenLake-v1', desc=None, map_name="4x4", is_slippery=False)
    agent = DQNAgent(input_dim=16, output_dim=4)
    rewards = []
    epsilons = []
    
    for episode in range(episodes):
        state, _ = env.reset()
        state = processLakestate(state)
        totalReward = 0
        done = False   
        while not done:
            action = agent.actionFun(state)
            nxt_st, reward, done, _, _ = env.step(action)   
            if done and reward == 0:
                reward = -1
            elif done and reward == 1: 
                reward = 10
            else: 
                reward = -0.01 
            nxt_st = processLakestate(nxt_st)
            agent.addExptoBuff(state, action, reward, nxt_st, done)
            agent.replay() 
            state = nxt_st
            totalReward += reward
        rewards.append(totalReward)
        epsilons.append(agent.epsi)
        if (episode+1) % 100 == 0:
            avg = np.mean(rewards[-100:])
            print(f"For the episode {episode+1} we got avg reward as: {avg:.2f} and the current value for epsilon is: {agent.epsi:.2f}")
    np.save("lakedqn_rewards.npy", rewards)
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    plt.plot(rewards)
    plt.title(f"{env} Training Rewards")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.subplot(1,2,2)
    plt.plot(epsilons)
    plt.title("Epsilon Decay")
    plt.xlabel("Episode")
    plt.ylabel("Epsilon Value")
    plt.show()
    plt.close()
    return agent

# %%
agent = DQNAgent(input_dim=3, output_dim=6)
autodrone_agent = train_autodrone(agent)
torch.save(autodrone_agent.qnet.state_dict(), 'autodrone.pth')
model_weights = autodrone_agent.qnet.state_dict()
with open("droneModel_weights.pkl", "wb") as f:
    pickle.dump(model_weights, f)
# Out:
# The episode number is 100 for this we got average reward as: -2534.10 and the current epsilon value is: 0.01
# The episode number is 200 for this we got average reward as: 101.00 and the current epsilon value is: 0.01
# The episode number is 300 for this we got average reward as: 103.75 and the current epsilon value is: 0.01
# The episode number is 400 for this we got average reward as: 102.75 and the current epsilon value is: 0.01
# The episode number is 500 for this we got average reward as: 102.79 and the current epsilon value is: 0.01
# The episode number is 600 for this we got average reward as: 107.95 and the current epsilon value is: 0.01
# The episode number is 700 for this we got average reward as: 106.91 and the current epsilon value is: 0.01
# The episode number is 800 for this we got average reward as: 103.19 and the current epsilon value is: 0.01
# The episode number is 900 for this we got average reward as: 102.66 and the current epsilon value is: 0.01
# The episode number is 1000 for this we got average reward as: 104.83 and the current epsilon value is: 0.01

# %%
cartpole_agent = train_cartpole()
torch.save(cartpole_agent.qnet.state_dict(), 'cartpole.pth')
model_weights = cartpole_agent.qnet.state_dict()
with open("cartPoleModel_weights.pkl", "wb") as f:
    pickle.dump(model_weights, f)
# Out:
# The episode number is 100 for this we got average reward as: 171.73 the current epsilon value is: 0.01
# The episode number is 200 for this we got average reward as: 361.27 the current epsilon value is: 0.01
# The episode number is 300 for this we got average reward as: 348.42 the current epsilon value is: 0.01
# The episode number is 400 for this we got average reward as: 357.60 the current epsilon value is: 0.01
# The episode number is 500 for this we got average reward as: 390.11 the current epsilon value is: 0.01

# %%
frozenlake_agent = train_frozenlake()
torch.save(frozenlake_agent.qnet.state_dict(), 'frozenlake.pth')
model_weights = frozenlake_agent.qnet.state_dict()
with open("frozenLakeModel_weights.pkl", "wb") as f:
    pickle.dump(model_weights, f)
# Out:
# For the episode 100 we got avg reward as: 5.44 and the current value for epsilon is: 0.01
# For the episode 200 we got avg reward as: 9.95 and the current value for epsilon is: 0.01
# For the episode 300 we got avg reward as: 9.84 and the current value for epsilon is: 0.01
# For the episode 400 we got avg reward as: 9.60 and the current value for epsilon is: 0.01
# For the episode 500 we got avg reward as: 9.95 and the current value for epsilon is: 0.01
# For the episode 600 we got avg reward as: 9.95 and the current value for epsilon is: 0.01
# For the episode 700 we got avg reward as: 9.84 and the current value for epsilon is: 0.01
# For the episode 800 we got avg reward as: 9.84 and the current value for epsilon is: 0.01
# For the episode 900 we got avg reward as: 9.95 and the current value for epsilon is: 0.01
# For the episode 1000 we got avg reward as: 9.95 and the current value for epsilon is: 0.01
# For the episode 1100 we got avg reward as: 9.51 and the current value for epsilon is: 0.01
# For the episode 1200 we got avg reward as: 9.84 and the current value for epsilon is: 0.01
# For the episode 1300 we got avg reward as: 9.84 and the current value for epsilon is: 0.01
# For the episode 1400 we got avg reward as: 9.73 and the current value for epsilon is: 0.01
# For the episode 1500 we got avg reward as: 9.95 and the current value for epsilon is: 0.01
# For the episode 1600 we got avg reward as: 9.84 and the current value for epsilon is: 0.01
# For the episode 1700 we got avg reward as: 9.62 and the current value for epsilon is: 0.01
# For the episode 1800 we got avg reward as: 9.72 and the current value for epsilon is: 0.01
# For the episode 1900 we got avg reward as: 9.71 and the current value for epsilon is: 0.01
# For the episode 2000 we got avg reward as: 9.93 and the current value for epsilon is: 0.01

# %%
def evalAgent(env, agent, process_state, episodes=5, env_name="Environment"):
    total_rewards = []
    
    for ep in range(episodes):
        obs, info = env.reset()
        state = process_state(obs)
        total_reward = 0
        terminated = False
        truncated = False
        while not (terminated or truncated):
            with torch.no_grad():
                state_tensor = state.unsqueeze(0) if state.dim() == 1 else state
                q_values = agent.qnet(state_tensor)
                action = torch.argmax(q_values).item()
            next_obs, reward, terminated, truncated, info = env.step(action)
            state = process_state(next_obs)
            total_reward += reward
        total_rewards.append(total_reward)
        print(f"Episode {ep+1}: Reward = {total_reward}")
    plt.figure(figsize=(10, 5))
    plt.bar(range(1, episodes+1), total_rewards)  
    plt.title(f"Evaluation Results for {env_name}")
    plt.xlabel("Episode")
    plt.ylabel("Total Reward")
    plt.xticks(range(1, episodes+1))
    plt.grid(True, alpha=0.3)
    plt.savefig(f"drone_evaluation.png")
    plt.close()
    
    return total_rewards

# %%
def rendFun(agent):
    env = AutoDrone()
    state, _ = env.reset()
    frames = []
    env.curr_pos = env.pos
    env.package = env.has_package
    env.grid_s = env.grid_size
    env.warehouse_loc = env.warehouse
    env.delivery_loc = env.delivery

    while True:
        env.curr_pos = env.pos
        env.package = env.has_package
        frame = env.render(mode='rgb_array', plot=False)
        frames.append(Image.fromarray(frame))
        with torch.no_grad():
            q_values = agent.qnet(processDronestate(state))       #Selecting only greedy action here
            action = torch.argmax(q_values).item()

        next_state, reward, done, _, _ = env.step(action)
        state = next_state

        if done:
            break
    frames[0].save('autodrone_episode.gif', save_all=True, append_images=frames[1:], duration=500, loop=0)

# %%
cartpole_env = gym.make("CartPole-v1", render_mode="rgb_array")
frozenlake_env = gym.make("FrozenLake-v1", render_mode="rgb_array", is_slippery=True)
autodrone_env = AutoDrone()

# %%
cartpole_rewards = evalAgent(cartpole_env, cartpole_agent, processPolestate,env_name="cartpole")
frozenlake_rewards = evalAgent(frozenlake_env, frozenlake_agent, processLakestate, env_name="Frozenlake")
autodrone_rewards = evalAgent(autodrone_env, autodrone_agent, processDronestate,env_name="AutoDrone")
# Out:
# Episode 1: Reward = 500.0
# Episode 2: Reward = 500.0
# Episode 3: Reward = 500.0
# Episode 4: Reward = 500.0
# Episode 5: Reward = 500.0
# Episode 1: Reward = 0.0
# Episode 2: Reward = 0.0
# Episode 3: Reward = 0.0
# Episode 4: Reward = 1.0
# Episode 5: Reward = 0.0
# Episode 1: Reward = 108
# Episode 2: Reward = 113
# Episode 3: Reward = 107
# Episode 4: Reward = 110
# Episode 5: Reward = 112

# %%
rendFun(autodrone_agent)
